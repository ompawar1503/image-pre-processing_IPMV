# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Load the image (grayscale or binary)
image = cv2.imread('/content/ganeshji.jpeg', cv2.IMREAD_GRAYSCALE)

# Create a kernel (3x3 square kernel)
kernel = np.ones((3, 3), np.uint8)

# Apply erosion
eroded_image = cv2.erode(image, kernel, iterations=1)

# Display the original and eroded images
cv2_imshow(image) # Use cv2_imshow instead of cv2.imshow
cv2_imshow(eroded_image) # Use cv2_imshow instead of cv2.imshow

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-05f7507945b7> in <cell line: 0>()
#      16 cv2_imshow(eroded_image) # Use cv2_imshow instead of cv2.imshow
#      17
# ---> 18 cv2.waitKey(0)
#      19 cv2.destroyAllWindows()
#
# error: OpenCV(4.11.0) /io/opencv/modules/highgui/src/window.cpp:1367: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvWaitKey'
