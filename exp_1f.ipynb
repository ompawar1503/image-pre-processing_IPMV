# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Load an image
image = cv2.imread('/content/ganeshji.jpeg')

# Apply Averaging Blur
blurred_image = cv2.blur(image, (5, 5))  # (5, 5) is the kernel size

# Display the original and blurred images
cv2_imshow(image) # Use cv2_imshow instead of cv2.imshow
cv2_imshow(blurred_image) # Use cv2_imshow instead of cv2.imshow

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# <PIL.Image.Image image mode=RGB size=225x225>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-a0069acc497b> in <cell line: 0>()
#      13 cv2_imshow(blurred_image) # Use cv2_imshow instead of cv2.imshow
#      14
# ---> 15 cv2.waitKey(0)
#      16 cv2.destroyAllWindows()
#
# error: OpenCV(4.11.0) /io/opencv/modules/highgui/src/window.cpp:1367: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvWaitKey'
